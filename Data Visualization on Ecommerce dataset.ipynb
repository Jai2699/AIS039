# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv("C:\\Users\\HP\\Documents\\Ecommerce Customers")

# %%
data.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
sns.jointplot(x='Time on App',y='Yearly Amount Spent', data=data)

# %%
sns.jointplot(x='Time on Website',y='Yearly Amount Spent', data=data)

# %%
sns.relplot(x='Yearly Amount Spent',y='Avatar', data=data)

# %%
sns.relplot(x='Time on App',y='Yearly Amount Spent', data=data,kind='line')

# %%
sns.relplot(x='Time on Website',y='Yearly Amount Spent', data=data,kind='line')

# %%
sns.relplot(x='Avg. Session Length',y='Yearly Amount Spent', data=data,kind='line')

# %%
sns.relplot(x='Length of Membership',y='Yearly Amount Spent', data=data,kind='line')

# %%
sns.catplot(x='Time on App',y='Yearly Amount Spent', data=data)

# %%
sns.catplot(x='Avatar',y='Yearly Amount Spent', data=data)

# %%
sns.catplot(x='Time on Website',y='Yearly Amount Spent', data=data)

# %%
sns.catplot(x='Time on App',y='Yearly Amount Spent', kind='violin',data=data)

# %%
sns.catplot(x='Avatar',y='Yearly Amount Spent', kind='violin',data=data)

# %%
sns.catplot(x='Time on App',y='Yearly Amount Spent', kind='boxen',data=data)

# %%
sns.distplot(data["Yearly Amount Spent"])

# %%
sns.distplot(data["Time on App"])

# %%
x=data.iloc[:,3:4]
y=data.iloc[:,7:8]

# %%
sns.jointplot(x=x,y=y, kind='kde', color='b')

# %%
sns.set(style="darkgrid")
a=data
b=sns.PairGrid(a)
b.map(plt.scatter)

# %% [markdown]
# We can see spread of data from this.

# %%
sns.boxplot(x='Time on App', data=data)

# %%
sns.boxplot(x='Length of Membership', data=data)

# %% [markdown]
# From this boxplot, we may say that the spread of Membership is normally distributed also it has max 7 and min 0, But it highly lies between 3 to 4

# %%
sns.heatmap(data.corr(),annot=True)
