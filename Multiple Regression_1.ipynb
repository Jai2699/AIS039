# %% [markdown]
# # MODEL 1: Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math 
plt.rcParams['figure.figsize']=(12.0,9.0)
data=pd.read_csv("C:\\Users\\HP\\Documents\\Datasets\\House pred.csv")

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
#Separating ind and dep var
x=data.iloc[:,4:5]
y=data.iloc[:,1:2]

# %%
#Splitting data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.3,random_state=101)

#model fitting
from sklearn.linear_model import LinearRegression
linear_regressor=LinearRegression()
linear_regressor.fit(x_train,y_train)
#intercept
print("intercept: ",linear_regressor.intercept_)
print("coefficient: ",linear_regressor.coef_)
# Out:
# intercept:  [23396.21890958]
# coefficient:  [[249.28812701]]

# %%
y_pred=linear_regressor.predict(x_test)
print(y_pred)
# Out:
# [[1377030.74857878]
#  [ 589280.26722433]
#  [ 539422.64182215]
#  ...
#  [ 417271.4595868 ]
#  [ 310077.56497212]
#  [ 270191.46465037]]

# %%
#MSE and RMSE
from sklearn.metrics import mean_squared_error
import math
MSE= np.sqrt(mean_squared_error(y_test, y_pred))
RMSE=math.sqrt(MSE)
print('MSE: ', MSE)
print('RMSE: ',RMSE)
# Out:
# MSE:  434821.16126118635
# RMSE:  659.4097066780155

# %% [markdown]
# # MODEL 2:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(12.0,9.0)
data=pd.read_csv("C:\\Users\\HP\\Documents\\Datasets\\House pred.csv")

# %%
# separate ind and dep var
x=data[['bedrooms', 'sqft_living']]
y=data.iloc[:,1:2]

#Splitting data
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1= train_test_split(x,y,test_size=0.3,random_state=101)

#model fitting
from sklearn.linear_model import LinearRegression
linear_regressor=LinearRegression()
linear_regressor.fit(x_train1,y_train1)
#intercept
print("intercept: ",linear_regressor.intercept_)
print("coefficient: ",linear_regressor.coef_)
# Out:
# intercept:  [133319.36067749]
# coefficient:  [[-49658.84288554    277.09999431]]

# %%
y_pred1=linear_regressor.predict(x_test1)
print(y_pred1)
# Out:
# [[1439336.95826255]
#  [ 613359.81911457]
#  [ 508280.97736616]
#  ...
#  [ 422160.82303763]
#  [ 402325.51125351]
#  [ 258671.82639214]]

# %%
from sklearn.metrics import mean_squared_error
import math
MSE2= np.sqrt(mean_squared_error(y_test1, y_pred1))
RMSE2=math.sqrt(MSE2)
print('MSE2: ', MSE2)
print('RMSE2: ',RMSE2)
# Out:
# MSE2:  432511.51674710884
# RMSE2:  657.6560778606922

# %% [markdown]
# # MODEL: 3
# # More than 2 ind var.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(12.0,9.0)
data=pd.read_csv("C:\\Users\\HP\\Documents\\Datasets\\House pred.csv")

# %%
# separate ind and dep var
x=data[['bedrooms', 'sqft_living','bathrooms','sqft_lot','floors']]
y=data.iloc[:,1:2]


#Splitting data
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1= train_test_split(x,y,test_size=0.3,random_state=101)

#model fitting
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train1,y_train1)
#intercept
print("intercept: ",lm.intercept_)
print("coefficient: ",lm.coef_)
# Out:
# intercept:  [133893.65556357]
# coefficient:  [[-5.30526258e+04  2.75633967e+02  1.36447257e+04 -6.21624096e-01
#   -4.14632898e+03]]

# %%
y_pred2=lm.predict(x_test1)
y_pred2
# Out:
# array([[1383322.24982473],
#        [ 621461.65229723],
#        [ 515267.31256675],
#        ...,
#        [ 424486.66299497],
#        [ 414863.83889897],
#        [ 252915.83993126]])

# %%
from sklearn.metrics import mean_squared_error
import math
MSE3= np.sqrt(mean_squared_error(y_test1, y_pred2))
RMSE3=math.sqrt(MSE3)
print('MSE3: ', MSE3)
print('RMSE3: ',RMSE3)
# Out:
# MSE3:  431344.9686230498
# RMSE3:  656.7685807215886

# %%
print("Interpretation using Mean Square Error: ")
if MSE<MSE2 and MSE<MSE3:
    print("MODEL 1 is better for further analysis than remaining two model.")
elif MSE2<MSE and MSE2<MSE3:
    print("MODEL 2 is better for further analysis than remaining two model.")
elif MSE3<MSE and MSE3<MSE2:
    print("MODEL 3 is better for further analysis than remaining two model.")
# Out:
# Interpretation using Mean Square Error:
# MODEL 3 is better for further analysis than remaining two model.
